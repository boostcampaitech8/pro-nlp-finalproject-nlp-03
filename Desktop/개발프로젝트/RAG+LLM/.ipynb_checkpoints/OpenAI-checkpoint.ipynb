# %%
# 패키지 설치
# %pip install -q python-dotenv langchain-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# .env 파일에 OPENAI_API_KEY 등록

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model_name='gpt-4o-mini')

# %%
ai_message = llm.invoke("제주대학교는 어디에 위치해있나요?")

# %%
ai_message.content
# Out:
# '제주대학교는 대한민국 제주특별자치도 제주시에서 위치하고 있습니다. 제주도의 중심부에 자리 잡고 있으며, 아름다운 자연 환경과 함께 학문적인 연구와 교육을 제공하는 대학교입니다.'

# %%
ai_message = llm.invoke("인프런에는 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '인프런은 다양한 분야의 온라인 강의를 제공하는 플랫폼입니다. 주로 IT, 프로그래밍, 디자인, 마케팅, 데이터 분석 등 다양한 주제에 대한 강의를 찾을 수 있습니다. 예를 들어, Python, Java, 웹 개발, 머신러닝, 데이터베이스, 모바일 앱 개발, UX/UI 디자인, 디지털 마케팅 등의 강의가 있습니다. \n\n특정 강의나 카테고리에 대한 정보가 필요하다면 인프런 웹사이트를 방문하여 검색해보시는 것을 추천드립니다.'

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '인프런은 다양한 분야의 온라인 강의를 제공하는 플랫폼으로, 주로 IT, 프로그래밍, 데이터 과학, 디자인, 마케팅 등의 주제를 다룹니다. 여기 몇 가지 인기 있는 강의 카테고리를 소개할게요:\n\n1. **프로그래밍**: Python, Java, JavaScript, C++, Ruby 등 다양한 언어에 대한 강의\n2. **웹 개발**: HTML, CSS, React, Vue.js, Node.js 등을 포함한 웹 개발 관련 강의\n3. **모바일 앱 개발**: iOS, 안드로이드 앱 개발에 대한 강의\n4. **데이터 분석 및 머신러닝**: 데이터 분석, 데이터 시각화, 머신러닝, 인공지능 관련 강의\n5. **디자인**: UI/UX 디자인, 그래픽 디자인, Photoshop, Illustrator 사용법 강의\n6. **마케팅**: 디지털 마케팅, SEO, 콘텐츠 마케팅 등\n7. **DevOps 및 클라우드**: AWS, Azure, Docker, Kubernetes 관련 강의\n\n인프런의 강의는 주로 실습 위주로 구성되어 있어서 실제 프로젝트에 적용할 수 있는 내용을 많이 다루고 있습니다. 더 구체적인 강의는 인프런 공식 웹사이트에서 확인할 수 있습니다.'
